# %%
import matplotlib.pyplot as plt

y = [200, 300, 400, 500 ,600, 700]
x1 = [576.8849711453188, 821.5838662405424, 1163.8044167409992, 1389.1557184780133, 1637.5147852623584, 1850.5185911705696]
x2 = [371.4368590594417, 532.0360458327075, 706.3957944681733, 838.8904440063355, 1023.1763833972748, 1145.3616413353343]
x3 = [328.21614074656765, 483.1511407195333, 635.900367869699, 823.326397503278, 897.8645365335574, 1050.1317252351525]
x4 = [540.8458368623398, 826.6090331951917, 1023.8773465860979, 1283.8081288638405, 1498.919828686942, 1734.8232729521062]

plt.figure(figsize=(10, 10))
plt.xlabel('Number of Virtual Machine/Application')
plt.ylabel('Energy Consumed including cooling (Kwh)')
classOne, = plt.plot(y, x1)
classTwo, = plt.plot(y, x2)
classThree, = plt.plot(y, x3)
classFour, = plt.plot(y, x4)

plt.legend([classOne, classTwo, classThree, classFour], ['Class One', 'Class Two', 'Class Three', 'Class Four'])

# %%
import matplotlib.pyplot as plt

y = [200, 300, 400, 500 ,600, 700]
x1 = [509.21537480514763, 798.4855172323554, 1022.033025545272, 1225.5341629390236, 1461.36404749278, 1567.348102885691]
x2 = [348.8855549167903, 488.09065270900396, 650.7875369453386, 813.4844211816733, 976.1813054180079, 1138.8781896543426]

plt.figure(figsize=(10, 10))
plt.xlabel('Number of Virtual Machine/Application')
plt.ylabel('Energy Consumed including cooling (Kwh)')
rule23, = plt.plot(y, x1)
rule232, = plt.plot(y, x2)

plt.legend([rule23, rule232], ['Rule 23', 'Rule 232'])
